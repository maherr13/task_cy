# %% [markdown]
# #Cloning the repo and creating venv and installing required packges

# %%
#cloning the repo
# !git clone https://github.com/HHousen/transformersum.git
# Out:
# Cloning into 'transformersum'...
# remote: Enumerating objects: 1396, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 1396 (delta 81), reused 80 (delta 39), pack-reused 1232
# Receiving objects: 100% (1396/1396), 11.98 MiB | 23.32 MiB/s, done.
# Resolving deltas: 100% (865/865), done.

# %%
# %cd transformersum
# Out:
# /content/transformersum

# %%
#installing conda
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:29
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 4.9.2

# %%
#Creating the required env
# !conda env create --file environment.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ...
# absl-py-1.0.0        | 95 KB     | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
# sphinxcontrib-devhel | 22 KB     | : 100% 1.0/1 [00:00<00:00,  7.70it/s]
# sphinxcontrib-jsmath | 7 KB      | : 100% 1.0/1 [00:00<00:00, 14.59it/s]
# pyu2f-0.1.5          | 31 KB     | : 100% 1.0/1 [00:00<00:00, 10.99it/s]
# libevent-2.1.10      | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.73it/s]
# snappy-1.1.8         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 18.43it/s]
# virtualenv-20.13.2   | 8.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.03it/s]
# libzlib-1.2.11       | 59 KB     | : 100% 1.0/1 [00:00<00:00, 15.16it/s]
# requests-2.27.1      | 53 KB     | : 100% 1.0/1 [00:00<00:00, 15.07it/s]
# libssh2-1.10.0       | 233 KB    | : 100% 1.0/1 [00:00<00:00,  9.36it/s]
# ...

# %%
#activating the env
# %%bash
source activate transformersum

# %%
#installing the reqiured packges
# !pip install rouge-score
# Out:
# ...
#   Using cached rouge_score-0.0.4-py2.py3-none-any.whl (22 kB)
# ...
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# ...
#      |████████████████████████████████| 15.7 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 126 kB 43.1 MB/s
# ...
#      |████████████████████████████████| 306 kB 43.3 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.7 MB/s
# ...
#   Using cached regex-2022.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
# ...

# %%
# !conda install numpy
# !conda install pytorch torchvision torchaudio cudatoolkit=11.3 -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py37h89c1867_1         983 KB  conda-forge
#     libblas-3.9.0              |11_linux64_openblas          12 KB  conda-forge
#     libcblas-3.9.0             |11_linux64_openblas          11 KB  conda-forge
#     liblapack-3.9.0            |11_linux64_openblas          11 KB  conda-forge
#     libopenblas-0.3.17         |pthreads_h8fe5266_1         9.2 MB  conda-forge
#     numpy-1.20.3               |   py37h038b26d_1         5.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.9 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !conda install spacy
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - spacy
#
#
# The following NEW packages will be INSTALLED:
#
#   catalogue          conda-forge/linux-64::catalogue-2.0.6-py37h89c1867_1
#   click              conda-forge/linux-64::click-8.0.4-py37h89c1867_0
#   colorama           conda-forge/noarch::colorama-0.4.4-pyh9f0ad1d_0
#   cymem              conda-forge/linux-64::cymem-2.0.6-py37hcd2ae1e_2
#   cython-blis        conda-forge/linux-64::cython-blis-0.7.6-py37hb1e94ed_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   importlib-metadata conda-forge/linux-64::importlib-metadata-4.11.2-py37h89c1867_0
#   jinja2             conda-forge/noarch::jinja2-3.0.3-pyhd8ed1ab_0
#   langcodes          conda-forge/noarch::langcodes-3.3.0-pyhd8ed1ab_0
#   markupsafe         conda-forge/linux-64::markupsafe-2.1.0-py37h540881e_1
#   murmurhash         conda-forge/linux-64::murmurhash-1.0.6-py37hcd2ae1e_2
# ...

# %%
# !pip install pytorch_lightning
# !pip install datasets
# Out:
# ...
#   Using cached pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
# ...
#   Using cached setuptools-59.5.0-py3-none-any.whl (952 kB)
# ...
#      |████████████████████████████████| 5.8 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 51.7 MB/s
# ...
#   Using cached torchmetrics-0.7.2-py3-none-any.whl (397 kB)
# ...
#      |██████████████████████████████▎ | 834.1 MB 1.5 MB/s eta 0:00:33tcmalloc: large alloc 1147494400 bytes == 0x56240c47a000 @  0x7f479440a615 0x5623d29b367c 0x5623d2a8798b 0x5623d29b41a2 0x5623d2a266c4 0x5623d2a26a9d 0x5623d2a4d544 0x5623d2994af2 0x5623d29c3030 0x5623d2a269c8 0x5623d2a5174a 0x5623d2994af2 0x5623d29c3030 0x5623d2a269c8 0x5623d2a4e1d9 0x5623d2a1654f 0x5623d2a4d789 0x5623d2a1654f 0x5623d2a4d789 0x5623d2a1654f 0x5623d2a4d789 0x5623d2995ead 0x5623d29b4c4e 0x5623d2a94e99 0x5623d2a25a5b 0x5623d2a26b59 0x5623d2a4d4ac 0x5623d2994af2 0x5623d29c3030 0x5623d2a269c8 0x5623d2a4e1d9
#      |████████████████████████████████| 881.9 MB 1.9 kB/s
# ...

# %%
# !pip install transformers torch_optimizer wandb
# Out:
# ...
#   Using cached transformers-4.17.0-py3-none-any.whl (3.8 MB)
# ...
#   Using cached torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
# ...
#   Using cached wandb-0.12.11-py2.py3-none-any.whl (1.7 MB)
# ...
#   Using cached pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# ...
#   Using cached sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
# ...
#   Using cached tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
# ...
#   Using cached yaspin-2.1.0-py3-none-any.whl (18 kB)
# ...
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# ...
#   Using cached shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# ...
#   Using cached psutil-5.9.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
# ...
#   Using cached promise-2.3-py3-none-any.whl
# ...
#   Using cached setproctitle-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (36 kB)
# ...
#   Using cached sentry_sdk-1.5.6-py2.py3-none-any.whl (144 kB)
# ...
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# ...

# %%
# !pip install --upgrade --no-cache-dir gdown
# !pip install -U scikit-learn
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 97 kB 6.7 MB/s
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14775 sha256=c418d27ce84734d602f4d92f44f855a5f677945eb0e952e13066b55d7259fbf7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cq9i4z5a/wheels/fb/c3/0e/c4d8ff8bfcb0461afff199471449f642179b74968c15b7a69c
# Successfully built gdown
# ...

# %% [markdown]
# #Downloading the data and Training the model

# %%
#downloaing the required data for training (processed and formatted on the required way)
# !gdown --id 1jyNdc0fhrriZXArV-9R2UJMHfdQaQV3D
# Out:
# /usr/local/lib/python3.7/site-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1jyNdc0fhrriZXArV-9R2UJMHfdQaQV3D
# To: /content/wikihow_extractive_compressed_5000.tar.gz
# 100% 191M/191M [00:02<00:00, 83.7MB/s]

# %%
#creating the folders to save the progress
import os

os.mkdir('/content/data/')
os.mkdir("/content/logs")
os.mkdir("/content/weights")

# %%
#Extracting the data to data directory 
# !tar -xf /content/wikihow_extractive_compressed_5000.tar.gz -C /content/data/

# %%
"""
Training Command The command is written as recommended in the documentation
model used : distalled roberta (for fast training)
optimizer_type adamw
number of epochs 2
warmup 1400
training 
testing
w&b supported
"""
# !python /content/transformersum/src/main.py --model_name_or_path distilroberta-base --model_type distilroberta --no_use_token_type_ids --use_custom_checkpoint_callback --data_path /content/data/wikihow_extractive_compressed_5000 --max_epochs 2 --accumulate_grad_batches 2 --warmup_steps 1400 --gradient_clip_val 1.0 --optimizer_type adamw --use_scheduler linear --classifier transformer_linear --do_train --do_test --batch_size 16 --data_type txt --default_root_dir /content/log_weights --weights_save_path /content/weights
# Out:
# /usr/local/lib/python3.7/site-packages/pytorch_lightning/loops/epoch/training_epoch_loop.py:49: LightningDeprecationWarning: Setting `max_steps = None` is deprecated in v1.5 and will no longer be supported in v1.7. Use `max_steps = -1` instead.
#   "Setting `max_steps = None` is deprecated in v1.5 and will no longer be supported in v1.7."
# /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:148: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f31262f22d0>)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint object at 0x7f31262f22d0>)`.
#   f"Setting `Trainer(checkpoint_callback={checkpoint_callback})` is deprecated in v1.5 and will "
# ...

# %% [markdown]
# # Testing the trained model / Test cases

# %%
# %cd /content/transformersum/src
# Out:
# /content/transformersum/src

# %%
# Loading the checkpoints we saved from at the training phase
from extractive import ExtractiveSummarizer
model = ExtractiveSummarizer.load_from_checkpoint("/content/weights/transformerextsum-private/1urmoizn/checkpoints/epoch=1-step=933.ckpt")

# %%
# Case 1 
text_to_summarize = """This means that on the average about 9% of the words in the human abstractive summaries do not appear in the documents.
 Since extractive automatic summarizers extract all the sentences from the documents given to them for summarization,
  clearly no extractive summarizer can have Rouge-1 recall score higher than the documents themselves on any dataset,
   and, in general, the recall score will be lower since the summaries are limited to 100 words whereas the documents themselves can be arbitrarily long."""
summary = model.predict(text_to_summarize , num_summary_sentences=1)

# %%
summary
# Out:
# 'This means that on the average about 9 % of the words in the human abstractive summaries do not appear in the documents.'

# %%
# Case 2
text_to_summarize = """Egypt, a country linking northeast Africa with the Middle East, dates to the time of the pharaohs. Millennia-old monuments sit along the fertile Nile River Valley, including Giza's colossal Pyramids and Great Sphinx as well as Luxor's hieroglyph-lined Karnak Temple and Valley of the Kings tombs. The capital, Cairo, is home to Ottoman landmarks like Muhammad Ali Mosque and the Egyptian Museum, a trove of antiquities."""
summary = model.predict(text_to_summarize , num_summary_sentences=2)

# %%
summary
# Out:
# 'Egypt , a country linking northeast Africa with the Middle East , dates to the time of the pharaohs. The capital , Cairo , is home to Ottoman landmarks like Muhammad Ali Mosque and the Egyptian Museum , a trove of antiquities.'

# %%
# Case 3
text_to_summarize = """It felt like a scene from the Cold War, a perilous episode from a bygone era. An unpredictable Russian leader was amassing troops and tanks on a neighbor’s border. There was fear of a bloody East-West conflagration.

Then the cold war turned hot: Vladimir Putin ordered Russian forces to invade Ukraine. The repercussions were immediate, and far-reaching.

In the days ahead of the invasion, even as Russian forces reached an estimated strength of 190,000, and even as the United States warned in increasingly dire tones that a military strike appeared inevitable, Mr. Putin was claiming that he was open to diplomacy, and European leaders were working desperately to persuade the Kremlin to stand down.

Then on Feb. 24, the Russian president, addressing his nation, declared the start of a “special military operation” in Ukraine.

Now, the largest mobilization of forces Europe has seen since 1945 is underway, with Ukrainian soldiers and civilian resistance fighters battling to fend off a Russian assault on multiple fronts.

On Monday, talks began between Russian and Ukrainian delegations in Belarus, a close ally of Moscow’s, but more movement took place on the battlefield than at the negotiating table. A 17-mile-long Russian convoy was reported making its way toward the capital, Kyiv. And in a chilling escalation, a barrage of Russian rockets hit a residential neighborhood in Ukraine’s second-largest city, Kharkiv, where at least nine civilians were killed and dozens injured.

Outside observers speculated that Mr. Putin, frustrated by the surprisingly slow advance of his forces — which greatly outmatch Ukraine’s but have faced stiff resistance from Ukrainian soldiers and civilians alike — may have grown impatient and decided to intensify the military barrage. That could signal more civilian casualties ahead, they said.

The number of refugees who have fled the country has topped half a million. And Mr. Putin appears intent on capturing the Ukrainian capital, Kyiv, toppling Ukraine’s democratically elected government, and subsuming the country into Russia’s orbit."""
summary = model.predict(text_to_summarize , num_summary_sentences=3)

# %%
summary
# Out:
# 'It felt like a scene from the Cold War , a perilous episode from a bygone era. \n\n Then the cold war turned hot : Vladimir Putin ordered Russian forces to invade Ukraine. \n\n Then on Feb. 24 , the Russian president , addressing his nation , declared the start of a “ special military operation ” in Ukraine.'
